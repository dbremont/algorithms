# %%
# pip install -U sentence-transformers

from sentence_transformers import SentenceTransformer
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load model
model = SentenceTransformer('all-mpnet-base-v2')

objects = [
    "Sovereign State. A political entity...",
    "Corporation. A legal economic organization...",
    "Government Agency. A bureaucratic institution...",
    "Political Party. An organized political actor..."
]

# Generate embeddings
embeddings = model.encode(texts)

# Convert to numpy array
X = np.array(embeddings)

# Run t-SNE
tsne = TSNE(n_components=2, random_state=42, perplexity=2)
vectors_2d = tsne.fit_transform(X)

# %%
# Plot
plt.scatter(vectors_2d[:,0], vectors_2d[:,1])

for i, label in enumerate(texts):
    plt.annotate(label.split(".")[0], (vectors_2d[i,0], vectors_2d[i,1]))

plt.show()
